# %%
import unittest


class CajaNegraTest(unittest.TestCase):
    def test_confirma_texto(self):
        
        self.assertEqual(2,2,'se asemeja')

# %%
unittest.main(argv=[""], verbosity=2, exit=False)
test_confirma_texto(__main__.CajaNegraTest)
# Out:
# test_confirma_texto (__main__.CajaNegraTest.test_confirma_texto) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# OK
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\vs\prepcuso\Python-Prepcurso-larry\M09_errorhandling\blackbox\manejo_errores.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/d%3A/vs/prepcuso/Python-Prepcurso-larry/M09_errorhandling/blackbox/manejo_errores.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> unittest.main(argv=[""], verbosity=2, exit=False)
# ----> <a href='vscode-notebook-cell:/d%3A/vs/prepcuso/Python-Prepcurso-larry/M09_errorhandling/blackbox/manejo_errores.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> test_confirma_texto(__main__.CajaNegraTest)
#
# NameError: name 'test_confirma_texto' is not defined
